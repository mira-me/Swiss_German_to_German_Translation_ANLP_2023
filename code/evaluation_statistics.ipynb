# %%
# !pip install sacrebleu -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.3/106.3 kB 1.4 MB/s eta 0:00:00

# %%
import sacrebleu
import pandas as pd
import numpy as np

# %%
# The project folder can be saved in google drive and accessed through Google colab
from google.colab import drive
# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# path to the project folder that contains a folder code, data and models
path_project = "/content/drive/MyDrive/anlp_project/NLLB-200/ANLP_SUBMISSION"

import os
os.chdir(path_project)

# %%
def evaluate(df, columns_to_evaluate, ref_col="de"):
    for column in columns_to_evaluate:
        bleu_calc = sacrebleu.BLEU()
        chrf_calc = sacrebleu.CHRF(word_order=2)
        ter_calc = sacrebleu.TER()
        bleu = bleu_calc.corpus_score(df[column].tolist(), [df[ref_col].tolist()], n_bootstrap=1000)
        chrf = chrf_calc.corpus_score(df[column].tolist(), [df[ref_col].tolist()], n_bootstrap=1000)
        ter = ter_calc.corpus_score(df[column].tolist(), [df[ref_col].tolist()], n_bootstrap=1000)
        print(column)
        print(bleu)
        print(chrf)
        print(ter)
        print("---------------------")

# %% [markdown]
# # Test Set

# %%
df_test = pd.read_excel(f"data/Results/df_test_Results.xlsx")
df_test.head()
# Out:
#      id                                                 de  \
# 0   668  Es fällt nur wenigen Menschen auf, ob ein paar...
# 1   879  Die Spur führte zu einem Fisch- und Meeresfrüc...
# 2   373  Weltmeister wurde Brasilien im Finale gegen It...
# 3  2493     Er atmete schwer, als wäre er bergauf gerannt.
# 4  1813  Winterlicher Sonntag mit teilweise kräftigem S...
#
#                                                ch_sg  \
# 0  Es fallt nur wenige Mensche uf, ob es paar Wöl...
# 1  dSpur het zumne Fisch- und Meeresfrüchte-Markt...
# 2  Weltmeischter isch Brasilie im Final geg Itali...
# 3  Er het schwer gschnuufed, als ob er berguf gre...
# 4  En winterliche Sunntig mit teilwiis chräftigem...
#
#                                                ch_be  \
# 0  Es faut numä wenigä Mönschä uf, ob es paar Wöu...
# 1  D Schpuur het zumene Märit vo Fisch und Meeres...
# 2  Brasiliä isch im Finau gägä Italiä Wäutmeischt...
# 3  är het schwäär gschnuufet, so aus ober bärguf ...
# 4  Winterlechä Sunntig mit teilwiis chräftigem Sc...
#
#                                                ch_gr  \
# 0  Es fallt nur weniga Menscha uf, ob as paar Wöl...
# 1  D Spur het zu nem Fisch- und Meeresfrüchte-Mar...
# 2  Weltmeister isch Brasilia im Final gega Italia...
# 3  Er het schwer gschnuuft, als wär er berguuf gs...
# 4  Winterlicha Sunntig mit teilwiis kräftigem Sch...
#
#                                                ch_zh  \
# 0  Es fallt nur paar wenige Mänsche uf, ob es paa...
# 1  D Spur hät zumne Fisch- und Meeresfrücht-Märt ...
# 2  Wältmeister isch Brasilie worde im Final gege ...
# 3  Er schnufed so fest wie wänner berguf grännt wär.
# 4  Winterliche Sunntig mit teilwis starche Schnee...
#
#                                                ch_vs  \
# 0  Es fallt nur wenige Mänsche üf, ob es paar Wel...
# 1  D'Spur fiehrt zu mu Fisch- und Meeresfricht-Mä...
# 2  Wältmeischter isch Brasilien im Final gägu Ita...
# 3  Är het schwer gschnüüfut, als wäri är bärgüf g...
# 4  Winterliche Sunntag mit teilwis chräftigum Sch...
#
#                                                ch_bs  \
# 0  Es fallt nur wenige Lüt uf, öb es paar Wölf od...
# 1  Die Spur het zu me Fisch- und Meeresfrüchte-Mä...
# 2  Wältmeister isch Brasilie im Finale gege Itali...
# 3  Är het schwer gschnuuft, wo är de Bärg ufe gre...
# 4  Winterliche Sunntig mit teilwiis kräftige Schn...
#
#                                                ch_ag  \
# 0  Es fallt nome wenig Mönsche uf, ob es paar Wöl...
# 1  D'Spur füehrt zomene Fesch- ond Meeresfröcht-M...
# 2  Weltmeischter esch Brasilie im Final gäge Ital...
# 3  Er het sehr schwer gschnufet, als wäre er de B...
# 4  En wenterleche Sonntig mit teilwis kräftigem S...
#
#                                                ch_lu  \
# 0  Es fallt nor wenig Mönsche uf, öb es par Wölf ...
# 1  D Spur hed zomene Fesch- ond Meeresfröchte-Mää...
# 2  Wältmeister esch Brasilie em Final gäge Italie...
# 3  Är hed schäwr gschnuuft, als wärer de Bärg ufe...
# 4  E winterleche Sonntig met teilwis heftige Schn...
#
#                            thema  code_switching  \
# 0  tiere-pflanzen-landwirtschaft             NaN
# 1                        medizin             NaN
# 2                        special             NaN
# 3                        special             NaN
# 4                      srf_meteo             NaN
#
#                                            init_none  \
# 0  Es fehle nur wenige Menschen auf, ob ein paar ...
# 1  Die Spur führte zu einem Markt von Fisch und M...
# 2  Brasilien wurde im Final Weltmeister gegen Ita...
# 3  Er schnappte schwer, so als wäre er über die B...
# 4  Winterliche Sonnentage mit teilweise kräftigem...
#
#                                              init_vs  \
# 0  Es braucht nur wenige Menschen auf, ob ein paa...
# 1  Die Spur führte zu einem Markt von Fisch und M...
# 2  Brasilien wurde im Final Weltmeister gegen Ita...
# 3  Er schnupfte schwer, so dass er oben auf der B...
# 4  Winterliche Sontags mit teilweise kräftigem Sc...
#
#                                        init_gr_large  \
# 0  Es faust nur wenige Menschen auf, ob ein paar ...
# 1  Die Spur führte zu einem Markt für Fisch und M...
# 2  Brasiliä wurde im Final Weltmeister gegen Ital...
# 3  Er hat schwärz geschnallt, so als wäre er ober...
# 4  Winterliche Sonntags mit teilweise kräftigem S...
#
#                                              init_de  \
# 0  Es fällt nur wenigen Menschen auf, ob ein paar...
# 1  Die Spüre führte zu einem Meer mit Fisch und M...
# 2  Brasilien wurde im Final gegen Italien Weltmei...
# 3  Er schnappte schwer, so als wäre er aus oberer...
# 4  Winterliche Sonnewende mit teilweise krachtige...
#
#                                        init_gr_small
# 0  Es fällt nur wenigen Menschen auf, ob ein paar...
# 1  Die Spur führte zu einem inzwischen geschlosse...
# 2  Brasilien wurde im Final gegen Italien Weltmei...
# 3  Er hat schwer geschnallt, so als wäre er über ...
# 4  Winterlehen Sonntag mit teilweise kräftigem Sc...

# %%
columns = ['init_none', 'init_vs', 'init_gr_large', 'init_de', 'init_gr_small']
evaluate(df_test, columns)
# Out:
# init_none
# BLEU = 51.23 (μ = 51.14 ± 3.99) 77.0/56.1/44.5/36.1 (BP = 0.998 ratio = 0.998 hyp_len = 1607 ref_len = 1610)
# chrF2++ = 74.47 (μ = 74.49 ± 2.45)
# TER = 30.75 (μ = 30.71 ± 3.11)
# ---------------------
# init_vs
# BLEU = 50.33 (μ = 50.28 ± 4.27) 77.8/56.1/43.5/34.5 (BP = 0.995 ratio = 0.995 hyp_len = 1602 ref_len = 1610)
# chrF2++ = 74.22 (μ = 74.24 ± 2.46)
# TER = 29.76 (μ = 29.69 ± 2.92)
# ---------------------
# init_gr_large
# BLEU = 54.92 (μ = 54.81 ± 4.28) 80.1/60.9/48.7/39.2 (BP = 0.994 ratio = 0.994 hyp_len = 1600 ref_len = 1610)
# chrF2++ = 77.10 (μ = 77.09 ± 2.47)
# TER = 26.73 (μ = 26.69 ± 2.93)
# ---------------------
# init_de
# BLEU = 50.89 (μ = 50.80 ± 4.34) 77.2/56.3/44.3/35.6 (BP = 0.995 ratio = 0.995 hyp_len = 1602 ref_len = 1610)
# chrF2++ = 73.68 (μ = 73.69 ± 2.59)
# TER = 30.96 (μ = 30.91 ± 3.18)
# ---------------------
# init_gr_small
# BLEU = 54.76 (μ = 54.82 ± 4.38) 79.1/60.0/48.8/39.8 (BP = 0.994 ratio = 0.994 hyp_len = 1600 ref_len = 1610)
# chrF2++ = 76.05 (μ = 76.13 ± 2.42)
# TER = 28.70 (μ = 28.54 ± 3.13)
# ---------------------

# %%
# Save the column to a text file (e.g., CSV) to use through sacrebleu command line tools
for column in columns:
    df_test[column].to_csv(f'data/Results/text_files/{column}.txt', index=False, header=False)
df_test["de"].to_csv(f'data/Results/ref_de.txt', index=False, header=False)

# %%
# %%bash
# path="data/Results/text_files/"
# sacrebleu "${path}ref_de.txt" -i "${path}/init_none.txt" "${path}/init_vs.txt" "${path}/init_gr_large.txt" "${path}/init_de.txt" "${path}/init_gr_small.txt" -m bleu chrf ter --paired-bs --format text
# Out:
# ╒══════════════════════════════════════════════════╤═════════════════════╤══════════════════════╤════════════════════╕
# │                                           System │  BLEU (μ ± 95% CI)  │  chrF2 (μ ± 95% CI)  │  TER (μ ± 95% CI)  │
# ╞══════════════════════════════════════════════════╪═════════════════════╪══════════════════════╪════════════════════╡
# │ Baseline: data/Results/text_files//init_none.txt │  51.7 (51.7 ± 3.8)  │  77.1 (77.1 ± 2.4)   │ 31.2 (31.2 ± 3.3)  │
# ├──────────────────────────────────────────────────┼─────────────────────┼──────────────────────┼────────────────────┤
# │             data/Results/text_files//init_vs.txt │  51.1 (51.0 ± 4.1)  │  76.7 (76.7 ± 2.4)   │ 30.4 (30.3 ± 3.0)  │
# │                                                  │    (p = 0.2048)     │     (p = 0.2028)     │    (p = 0.1748)    │
# ├──────────────────────────────────────────────────┼─────────────────────┼──────────────────────┼────────────────────┤
# │       data/Results/text_files//init_gr_large.txt │  55.8 (55.6 ± 4.1)  │  79.4 (79.4 ± 2.3)   │ 26.9 (26.9 ± 2.9)  │
# │                                                  │    (p = 0.0050)*    │    (p = 0.0060)*     │   (p = 0.0010)*    │
# ├──────────────────────────────────────────────────┼─────────────────────┼──────────────────────┼────────────────────┤
# │             data/Results/text_files//init_de.txt │  51.8 (51.6 ± 4.2)  │  76.1 (76.1 ± 2.5)   │ 31.4 (31.3 ± 3.2)  │
# │                                                  │    (p = 0.4076)     │     (p = 0.1009)     │    (p = 0.3516)    │
# ├──────────────────────────────────────────────────┼─────────────────────┼──────────────────────┼────────────────────┤
# │       data/Results/text_files//init_gr_small.txt │  55.6 (55.6 ± 4.2)  │  78.3 (78.4 ± 2.3)   │ 29.1 (28.9 ± 3.1)  │
# │                                                  │    (p = 0.0110)*    │     (p = 0.0679)     │   (p = 0.0470)*    │
# ╘══════════════════════════════════════════════════╧═════════════════════╧══════════════════════╧════════════════════╛
#
# ------------------------------------------------------------
# Paired bootstrap resampling test with 1000 resampling trials
# ------------------------------------------------------------
#  - Each system is pairwise compared to Baseline: data/Results/text_files//init_none.txt.
#    Actual system score / bootstrap estimated true mean / 95% CI are provided for each metric.
#
#  - Null hypothesis: the system and the baseline translations are essentially
#    generated by the same underlying process. For a given system and the baseline,
#    the p-value is roughly the probability of the absolute score difference (delta)
#    or higher occurring due to chance, under the assumption that the null hypothesis is correct.
#
#  - Assuming a significance threshold of 0.05, the null hypothesis can be rejected
#    for p-values < 0.05 (marked with "*"). This means that the delta is unlikely to be attributed
#    to chance, hence the system is significantly "different" than the baseline.
#    Otherwise, the p-values are highlighted in red.
#
#  - NOTE: Significance does not tell whether a system is "better" than the baseline but rather
#    emphasizes the "difference" of the systems in terms of the replicability of the delta.
#
# -----------------
# Metric signatures
# -----------------
#  - BLEU       nrefs:1|bs:1000|seed:12345|case:mixed|eff:no|tok:13a|smooth:exp|version:2.4.0
#  - chrF2      nrefs:1|bs:1000|seed:12345|case:mixed|eff:yes|nc:6|nw:0|space:no|version:2.4.0
#  - TER        nrefs:1|bs:1000|seed:12345|case:lc|tok:tercom|norm:no|punct:yes|asian:no|version:2.4.0
# sacreBLEU: Found 5 systems.
# sacreBLEU: Pre-computing BLEU statistics for 'Baseline: data/Results/text_files//init_none.txt'
# sacreBLEU: Pre-computing CHRF statistics for 'Baseline: data/Results/text_files//init_none.txt'
# sacreBLEU: Pre-computing TER statistics for 'Baseline: data/Results/text_files//init_none.txt'
# sacreBLEU: Computing BLEU for 'data/Results/text_files//init_vs.txt' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# sacreBLEU: Computing chrF2 for 'data/Results/text_files//init_vs.txt' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# sacreBLEU: Computing TER for 'data/Results/text_files//init_vs.txt' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# sacreBLEU: Computing BLEU for 'data/Results/text_files//init_gr_large.txt' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# sacreBLEU: Computing chrF2 for 'data/Results/text_files//init_gr_large.txt' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# sacreBLEU: Computing TER for 'data/Results/text_files//init_gr_large.txt' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# sacreBLEU: Computing BLEU for 'data/Results/text_files//init_de.txt' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# sacreBLEU: Computing chrF2 for 'data/Results/text_files//init_de.txt' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# sacreBLEU: Computing TER for 'data/Results/text_files//init_de.txt' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# sacreBLEU: Computing BLEU for 'data/Results/text_files//init_gr_small.txt' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# sacreBLEU: Computing chrF2 for 'data/Results/text_files//init_gr_small.txt' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# sacreBLEU: Computing TER for 'data/Results/text_files//init_gr_small.txt' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)

# %%
# %%bash
# path="data/Results/text_files/"
# sacrebleu "${path}ref_de.txt" -i "${path}/init_vs.txt" "${path}/init_gr_small.txt" -m bleu chrf ter --paired-bs --format text
# Out:
# ╒════════════════════════════════════════════════╤═════════════════════╤══════════════════════╤════════════════════╕
# │                                         System │  BLEU (μ ± 95% CI)  │  chrF2 (μ ± 95% CI)  │  TER (μ ± 95% CI)  │
# ╞════════════════════════════════════════════════╪═════════════════════╪══════════════════════╪════════════════════╡
# │ Baseline: data/Results/text_files//init_vs.txt │  51.1 (51.0 ± 4.1)  │  76.7 (76.7 ± 2.4)   │ 30.4 (30.3 ± 3.0)  │
# ├────────────────────────────────────────────────┼─────────────────────┼──────────────────────┼────────────────────┤
# │     data/Results/text_files//init_gr_small.txt │  55.6 (55.6 ± 4.2)  │  78.3 (78.4 ± 2.3)   │ 29.1 (28.9 ± 3.1)  │
# │                                                │    (p = 0.0020)*    │    (p = 0.0280)*     │    (p = 0.1149)    │
# ╘════════════════════════════════════════════════╧═════════════════════╧══════════════════════╧════════════════════╛
#
# ------------------------------------------------------------
# Paired bootstrap resampling test with 1000 resampling trials
# ------------------------------------------------------------
#  - Each system is pairwise compared to Baseline: data/Results/text_files//init_vs.txt.
#    Actual system score / bootstrap estimated true mean / 95% CI are provided for each metric.
#
#  - Null hypothesis: the system and the baseline translations are essentially
#    generated by the same underlying process. For a given system and the baseline,
#    the p-value is roughly the probability of the absolute score difference (delta)
#    or higher occurring due to chance, under the assumption that the null hypothesis is correct.
#
#  - Assuming a significance threshold of 0.05, the null hypothesis can be rejected
#    for p-values < 0.05 (marked with "*"). This means that the delta is unlikely to be attributed
#    to chance, hence the system is significantly "different" than the baseline.
#    Otherwise, the p-values are highlighted in red.
#
#  - NOTE: Significance does not tell whether a system is "better" than the baseline but rather
#    emphasizes the "difference" of the systems in terms of the replicability of the delta.
#
# -----------------
# Metric signatures
# -----------------
#  - BLEU       nrefs:1|bs:1000|seed:12345|case:mixed|eff:no|tok:13a|smooth:exp|version:2.4.0
#  - chrF2      nrefs:1|bs:1000|seed:12345|case:mixed|eff:yes|nc:6|nw:0|space:no|version:2.4.0
#  - TER        nrefs:1|bs:1000|seed:12345|case:lc|tok:tercom|norm:no|punct:yes|asian:no|version:2.4.0
# sacreBLEU: Found 2 systems.
# sacreBLEU: Pre-computing BLEU statistics for 'Baseline: data/Results/text_files//init_vs.txt'
# sacreBLEU: Pre-computing CHRF statistics for 'Baseline: data/Results/text_files//init_vs.txt'
# sacreBLEU: Pre-computing TER statistics for 'Baseline: data/Results/text_files//init_vs.txt'
# sacreBLEU: Computing BLEU for 'data/Results/text_files//init_gr_small.txt' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# sacreBLEU: Computing chrF2 for 'data/Results/text_files//init_gr_small.txt' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# sacreBLEU: Computing TER for 'data/Results/text_files//init_gr_small.txt' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)

# %%
# %%bash
# path="data/Results/text_files/"
# sacrebleu "${path}ref_de.txt" -i "${path}/init_vs.txt" "${path}/init_gr_large.txt" -m bleu chrf ter --paired-bs --format text
# Out:
# ╒════════════════════════════════════════════════╤═════════════════════╤══════════════════════╤════════════════════╕
# │                                         System │  BLEU (μ ± 95% CI)  │  chrF2 (μ ± 95% CI)  │  TER (μ ± 95% CI)  │
# ╞════════════════════════════════════════════════╪═════════════════════╪══════════════════════╪════════════════════╡
# │ Baseline: data/Results/text_files//init_vs.txt │  51.1 (51.0 ± 4.1)  │  76.7 (76.7 ± 2.4)   │ 30.4 (30.3 ± 3.0)  │
# ├────────────────────────────────────────────────┼─────────────────────┼──────────────────────┼────────────────────┤
# │     data/Results/text_files//init_gr_large.txt │  55.8 (55.6 ± 4.1)  │  79.4 (79.4 ± 2.3)   │ 26.9 (26.9 ± 2.9)  │
# │                                                │    (p = 0.0020)*    │    (p = 0.0020)*     │   (p = 0.0040)*    │
# ╘════════════════════════════════════════════════╧═════════════════════╧══════════════════════╧════════════════════╛
#
# ------------------------------------------------------------
# Paired bootstrap resampling test with 1000 resampling trials
# ------------------------------------------------------------
#  - Each system is pairwise compared to Baseline: data/Results/text_files//init_vs.txt.
#    Actual system score / bootstrap estimated true mean / 95% CI are provided for each metric.
#
#  - Null hypothesis: the system and the baseline translations are essentially
#    generated by the same underlying process. For a given system and the baseline,
#    the p-value is roughly the probability of the absolute score difference (delta)
#    or higher occurring due to chance, under the assumption that the null hypothesis is correct.
#
#  - Assuming a significance threshold of 0.05, the null hypothesis can be rejected
#    for p-values < 0.05 (marked with "*"). This means that the delta is unlikely to be attributed
#    to chance, hence the system is significantly "different" than the baseline.
#    Otherwise, the p-values are highlighted in red.
#
#  - NOTE: Significance does not tell whether a system is "better" than the baseline but rather
#    emphasizes the "difference" of the systems in terms of the replicability of the delta.
#
# -----------------
# Metric signatures
# -----------------
#  - BLEU       nrefs:1|bs:1000|seed:12345|case:mixed|eff:no|tok:13a|smooth:exp|version:2.4.0
#  - chrF2      nrefs:1|bs:1000|seed:12345|case:mixed|eff:yes|nc:6|nw:0|space:no|version:2.4.0
#  - TER        nrefs:1|bs:1000|seed:12345|case:lc|tok:tercom|norm:no|punct:yes|asian:no|version:2.4.0
# sacreBLEU: Found 2 systems.
# sacreBLEU: Pre-computing BLEU statistics for 'Baseline: data/Results/text_files//init_vs.txt'
# sacreBLEU: Pre-computing CHRF statistics for 'Baseline: data/Results/text_files//init_vs.txt'
# sacreBLEU: Pre-computing TER statistics for 'Baseline: data/Results/text_files//init_vs.txt'
# sacreBLEU: Computing BLEU for 'data/Results/text_files//init_gr_large.txt' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# sacreBLEU: Computing chrF2 for 'data/Results/text_files//init_gr_large.txt' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# sacreBLEU: Computing TER for 'data/Results/text_files//init_gr_large.txt' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)

# %%
# %%bash
# path="data/Results/text_files/"
# sacrebleu "${path}ref_de.txt" -i "${path}/init_de.txt" "${path}/init_vs.txt" "${path}/init_gr_large.txt" "${path}/init_gr_small.txt" -m bleu chrf ter --paired-bs --format text
# Out:
# ╒════════════════════════════════════════════════╤═════════════════════╤══════════════════════╤════════════════════╕
# │                                         System │  BLEU (μ ± 95% CI)  │  chrF2 (μ ± 95% CI)  │  TER (μ ± 95% CI)  │
# ╞════════════════════════════════════════════════╪═════════════════════╪══════════════════════╪════════════════════╡
# │ Baseline: data/Results/text_files//init_de.txt │  51.8 (51.6 ± 4.2)  │  76.1 (76.1 ± 2.5)   │ 31.4 (31.3 ± 3.2)  │
# ├────────────────────────────────────────────────┼─────────────────────┼──────────────────────┼────────────────────┤
# │           data/Results/text_files//init_vs.txt │  51.1 (51.0 ± 4.1)  │  76.7 (76.7 ± 2.4)   │ 30.4 (30.3 ± 3.0)  │
# │                                                │    (p = 0.2088)     │     (p = 0.1499)     │    (p = 0.1588)    │
# ├────────────────────────────────────────────────┼─────────────────────┼──────────────────────┼────────────────────┤
# │     data/Results/text_files//init_gr_large.txt │  55.8 (55.6 ± 4.1)  │  79.4 (79.4 ± 2.3)   │ 26.9 (26.9 ± 2.9)  │
# │                                                │    (p = 0.0110)*    │    (p = 0.0020)*     │   (p = 0.0040)*    │
# ├────────────────────────────────────────────────┼─────────────────────┼──────────────────────┼────────────────────┤
# │     data/Results/text_files//init_gr_small.txt │  55.6 (55.6 ± 4.2)  │  78.3 (78.4 ± 2.3)   │ 29.1 (28.9 ± 3.1)  │
# │                                                │    (p = 0.0170)*    │    (p = 0.0100)*     │   (p = 0.0450)*    │
# ╘════════════════════════════════════════════════╧═════════════════════╧══════════════════════╧════════════════════╛
#
# ------------------------------------------------------------
# Paired bootstrap resampling test with 1000 resampling trials
# ------------------------------------------------------------
#  - Each system is pairwise compared to Baseline: data/Results/text_files//init_de.txt.
#    Actual system score / bootstrap estimated true mean / 95% CI are provided for each metric.
#
#  - Null hypothesis: the system and the baseline translations are essentially
#    generated by the same underlying process. For a given system and the baseline,
#    the p-value is roughly the probability of the absolute score difference (delta)
#    or higher occurring due to chance, under the assumption that the null hypothesis is correct.
#
#  - Assuming a significance threshold of 0.05, the null hypothesis can be rejected
#    for p-values < 0.05 (marked with "*"). This means that the delta is unlikely to be attributed
#    to chance, hence the system is significantly "different" than the baseline.
#    Otherwise, the p-values are highlighted in red.
#
#  - NOTE: Significance does not tell whether a system is "better" than the baseline but rather
#    emphasizes the "difference" of the systems in terms of the replicability of the delta.
#
# -----------------
# Metric signatures
# -----------------
#  - BLEU       nrefs:1|bs:1000|seed:12345|case:mixed|eff:no|tok:13a|smooth:exp|version:2.4.0
#  - chrF2      nrefs:1|bs:1000|seed:12345|case:mixed|eff:yes|nc:6|nw:0|space:no|version:2.4.0
#  - TER        nrefs:1|bs:1000|seed:12345|case:lc|tok:tercom|norm:no|punct:yes|asian:no|version:2.4.0
# sacreBLEU: Found 4 systems.
# sacreBLEU: Pre-computing BLEU statistics for 'Baseline: data/Results/text_files//init_de.txt'
# sacreBLEU: Pre-computing CHRF statistics for 'Baseline: data/Results/text_files//init_de.txt'
# sacreBLEU: Pre-computing TER statistics for 'Baseline: data/Results/text_files//init_de.txt'
# sacreBLEU: Computing BLEU for 'data/Results/text_files//init_vs.txt' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# sacreBLEU: Computing chrF2 for 'data/Results/text_files//init_vs.txt' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# sacreBLEU: Computing TER for 'data/Results/text_files//init_vs.txt' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# sacreBLEU: Computing BLEU for 'data/Results/text_files//init_gr_large.txt' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# sacreBLEU: Computing chrF2 for 'data/Results/text_files//init_gr_large.txt' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# sacreBLEU: Computing TER for 'data/Results/text_files//init_gr_large.txt' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# sacreBLEU: Computing BLEU for 'data/Results/text_files//init_gr_small.txt' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# sacreBLEU: Computing chrF2 for 'data/Results/text_files//init_gr_small.txt' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)
# sacreBLEU: Computing TER for 'data/Results/text_files//init_gr_small.txt' and extracting sufficient statistics
# sacreBLEU:  > Performing paired bootstrap resampling test (# resamples: 1000)

# %% [markdown]
# # Synthetic Test Set

# %%
df_syn = pd.read_excel("data/Results/Manual_Syntax_Evaluation_Synt_TestSet.xlsx")

# %%
df_syn.columns
# Out:
# Index(['Unnamed: 0', 'Ids used', 'de', 'be', 'tab', 'init_none', 'Label',
#        'num_init_none', 'Issue', 'init_vs', 'Label.1', 'num_init_vs',
#        'Issue.1', 'init_gr_large', 'Label.2', 'num_init_gr_large', 'Issue.2',
#        'init_de', 'Label.3', 'num_init_de', 'Issue.3', 'init_gr_small', 'Rot',
#        'num_init_gr_small', 'Issue.4', 'Count of Correct Translations',
#        'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29',
#        'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33',
#        'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36'],
#       dtype='object')

# %%
evaluate(df_syn, ['init_none', 'init_vs', 'init_gr_large', 'init_de', 'init_gr_small'])
# Out:
# init_none
# BLEU = 58.05 (μ = 58.06 ± 6.44) 84.3/64.5/54.2/43.8 (BP = 0.968 ratio = 0.969 hyp_len = 561 ref_len = 579)
# chrF2++ = 77.26 (μ = 77.30 ± 3.76)
# TER = 26.05 (μ = 26.01 ± 4.52)
# ---------------------
# init_vs
# BLEU = 58.14 (μ = 58.12 ± 7.24) 85.1/66.1/55.2/45.8 (BP = 0.947 ratio = 0.948 hyp_len = 549 ref_len = 579)
# chrF2++ = 76.17 (μ = 76.21 ± 4.40)
# TER = 26.85 (μ = 26.82 ± 4.79)
# ---------------------
# init_gr_large
# BLEU = 68.07 (μ = 68.04 ± 6.68) 86.6/72.6/63.7/55.6 (BP = 0.991 ratio = 0.991 hyp_len = 574 ref_len = 579)
# chrF2++ = 83.22 (μ = 83.25 ± 3.94)
# TER = 18.24 (μ = 18.24 ± 4.61)
# ---------------------
# init_de
# BLEU = 65.48 (μ = 65.17 ± 6.52) 85.4/69.9/60.4/51.0 (BP = 1.000 ratio = 1.005 hyp_len = 582 ref_len = 579)
# chrF2++ = 82.21 (μ = 82.14 ± 3.66)
# TER = 21.24 (μ = 21.34 ± 4.91)
# ---------------------
# init_gr_small
# BLEU = 60.52 (μ = 60.48 ± 6.91) 84.0/65.5/55.3/46.9 (BP = 0.984 ratio = 0.984 hyp_len = 570 ref_len = 579)
# chrF2++ = 78.65 (μ = 78.68 ± 4.26)
# TER = 25.05 (μ = 25.04 ± 4.98)
# ---------------------

# %%
df_syn.columns
# Out:
# Index(['Unnamed: 0', 'Ids used', 'de', 'be', 'tab', 'init_none', 'Label',
#        'num_init_none', 'Issue', 'init_vs', 'Label.1', 'num_init_vs',
#        'Issue.1', 'init_gr_large', 'Label.2', 'num_init_gr_large', 'Issue.2',
#        'init_de', 'Label.3', 'num_init_de', 'Issue.3', 'init_gr_small', 'Rot',
#        'num_init_gr_small', 'Issue.4', 'Count of Correct Translations',
#        'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29',
#        'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33',
#        'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36'],
#       dtype='object')

# %%
cols = ["num_init_none", "num_init_vs", "num_init_gr_large", "num_init_de", "num_init_gr_small"]

# store only the columns with the numeric evaluation
df_syn_sub = df_syn[cols]

# %%
def eval_measure(array):
    """
    Function to get the accuracy for each column
    """
    return np.sum(array, axis=0)/ array.shape[0]

# print the accuracy for all columns
eval_measure(df_syn_sub)
# Out:
# num_init_none        0.583333
# num_init_vs          0.716667
# num_init_gr_large    0.866667
# num_init_de          0.816667
# num_init_gr_small    0.600000
# dtype: float64

# %%
def eval_with_paired_bootstrap(df, cols, num_samples=1000, sample_ratio=0.6):
    """
    Function to perform paired bootstrap resampling.
    """

    df = df[cols]

    array = np.array(df)
    sys1_scores = []
    sys2_scores = []
    wins = [0, 0, 0]

    print(eval_measure(array))

    for _ in range(num_samples):

        # shuffles along the first axis
        np.random.shuffle(array)

        # take the sample ratio
        ratio_samples = int(array.shape[0]*sample_ratio)

        # reduce the array
        array_reduced = array[:ratio_samples]

        # Calculate accuracy on the reduced sample and save stats
        score = eval_measure(array_reduced)

        if score[0] > score[1]:
            wins[0] += 1
        elif score[0] < score[1]:
            wins[1] += 1
        else:
            wins[2] += 1

        sys1_scores.append(score[0])
        sys2_scores.append(score[1])

    # Print win stats
    wins = [x/float(num_samples) for x in wins]
    print(f'Win ratio: sys1={wins[0]}, sys2={wins[1]}, tie={wins[2]}')
    if wins[0] > wins[1]:
        p_value = 1-wins[0]
        print('(sys1 is superior with p value p=%.3f)' % (p_value))
    elif wins[1] > wins[0]:
        p_value = 1-wins[1]
        print('(sys2 is superior with p value p=%.3f)' % (p_value))

    # Print system stats
    sys1_scores.sort()
    sys2_scores.sort()
    print('sys1 mean=%.3f, median=%.3f, 95%% confidence interval=[%.3f, %.3f]' %
        (np.mean(sys1_scores), np.median(sys1_scores), sys1_scores[int(num_samples * 0.025)], sys1_scores[int(num_samples * 0.975)]))
    print('sys2 mean=%.3f, median=%.3f, 95%% confidence interval=[%.3f, %.3f]' %
        (np.mean(sys2_scores), np.median(sys2_scores), sys2_scores[int(num_samples * 0.025)], sys2_scores[int(num_samples * 0.975)]))

    return p_value

# %%
# define the hypothesis which for the comparison

sq0 = [["num_init_none", "num_init_vs"],
       ["num_init_none", "num_init_gr_large"],
       ["num_init_none", "num_init_de"],
       ["num_init_none", "num_init_gr_small"]
      ]

sq1 = [["num_init_gr_small", "num_init_vs"]]

sq2 = [["num_init_gr_large", "num_init_vs"]]

sq3 = [["num_init_de", "num_init_vs"],
       ["num_init_de", "num_init_gr_large"],
       ["num_init_de", "num_init_gr_small"]
      ]

sqs = {"sq0": sq0, "sq1": sq1, "sq2": sq2, "sq3": sq3}

# %%
pairs = [" ".join(pair) for sq in sqs.values() for pair in sq]

df_p_values = pd.DataFrame({"pairs": pairs})

pairs = []
p_values = []
s_ratio = 0.6

for hypothesis, sq in sqs.items():

    for pair in sq:
        print(f"{hypothesis}\nPair: {pair}\n------------------")
        p = eval_with_paired_bootstrap(df_syn_sub, cols=pair, sample_ratio=s_ratio)
        pairs.append(" ".join(pair))
        p_values.append(p)

df_p_values[str(s_ratio)] = p_values
# Out:
# sq0
# Pair: ['num_init_none', 'num_init_vs']
# ------------------
# [0.58333333 0.71666667]
# Win ratio: sys1=0.013, sys2=0.951, tie=0.036
# (sys2 is superior with p value p=0.049)
# sys1 mean=0.585, median=0.583, 95% confidence interval=[0.472, 0.694]
# sys2 mean=0.717, median=0.722, 95% confidence interval=[0.639, 0.806]
# sq0
# Pair: ['num_init_none', 'num_init_gr_large']
# ------------------
# [0.58333333 0.86666667]
# Win ratio: sys1=0.0, sys2=1.0, tie=0.0
# (sys2 is superior with p value p=0.000)
# sys1 mean=0.582, median=0.583, 95% confidence interval=[0.500, 0.667]
# sys2 mean=0.866, median=0.861, 95% confidence interval=[0.806, 0.944]
# sq0
# Pair: ['num_init_none', 'num_init_de']
# ------------------
# [0.58333333 0.81666667]
# Win ratio: sys1=0.0, sys2=1.0, tie=0.0
# (sys2 is superior with p value p=0.000)
# sys1 mean=0.583, median=0.583, 95% confidence interval=[0.472, 0.694]
# sys2 mean=0.817, median=0.806, 95% confidence interval=[0.750, 0.889]
# sq0
# Pair: ['num_init_none', 'num_init_gr_small']
# ------------------
# [0.58333333 0.6       ]
# Win ratio: sys1=0.309, sys2=0.5, tie=0.191
# (sys2 is superior with p value p=0.500)
# sys1 mean=0.585, median=0.583, 95% confidence interval=[0.472, 0.694]
# sys2 mean=0.599, median=0.611, 95% confidence interval=[0.500, 0.694]
# sq1
# Pair: ['num_init_gr_small', 'num_init_vs']
# ------------------
# [0.6        0.71666667]
# Win ratio: sys1=0.015, sys2=0.947, tie=0.038
# (sys2 is superior with p value p=0.053)
# sys1 mean=0.599, median=0.611, 95% confidence interval=[0.500, 0.694]
# sys2 mean=0.714, median=0.722, 95% confidence interval=[0.611, 0.806]
# sq2
# Pair: ['num_init_gr_large', 'num_init_vs']
# ------------------
# [0.86666667 0.71666667]
# Win ratio: sys1=0.995, sys2=0.0, tie=0.005
# (sys1 is superior with p value p=0.005)
# sys1 mean=0.867, median=0.861, 95% confidence interval=[0.806, 0.944]
# sys2 mean=0.718, median=0.722, 95% confidence interval=[0.639, 0.806]
# sq3
# Pair: ['num_init_de', 'num_init_vs']
# ------------------
# [0.81666667 0.71666667]
# Win ratio: sys1=0.941, sys2=0.014, tie=0.045
# (sys1 is superior with p value p=0.059)
# sys1 mean=0.817, median=0.806, 95% confidence interval=[0.750, 0.889]
# sys2 mean=0.715, median=0.722, 95% confidence interval=[0.611, 0.806]
# sq3
# Pair: ['num_init_de', 'num_init_gr_large']
# ------------------
# [0.81666667 0.86666667]
# Win ratio: sys1=0.087, sys2=0.779, tie=0.134
# (sys2 is superior with p value p=0.221)
# sys1 mean=0.817, median=0.806, 95% confidence interval=[0.750, 0.889]
# sys2 mean=0.868, median=0.861, 95% confidence interval=[0.806, 0.944]
# sq3
# Pair: ['num_init_de', 'num_init_gr_small']
# ------------------
# [0.81666667 0.6       ]
# Win ratio: sys1=1.0, sys2=0.0, tie=0.0
# (sys1 is superior with p value p=0.000)
# sys1 mean=0.818, median=0.806, 95% confidence interval=[0.750, 0.889]
# sys2 mean=0.602, median=0.611, 95% confidence interval=[0.500, 0.694]

# %%
df_p_values
# Out:
#                              pairs    0.6
# 0        num_init_none num_init_vs  0.049
# 1  num_init_none num_init_gr_large  0.000
# 2        num_init_none num_init_de  0.000
# 3  num_init_none num_init_gr_small  0.500
# 4    num_init_gr_small num_init_vs  0.053
# 5    num_init_gr_large num_init_vs  0.005
# 6          num_init_de num_init_vs  0.059
# 7    num_init_de num_init_gr_large  0.221
# 8    num_init_de num_init_gr_small  0.000
